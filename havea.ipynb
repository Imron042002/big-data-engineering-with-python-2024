# %%
import pandas as pd
import cassandra
import re
import os
import glob
import numpy as np
import json
import csv
import matplotlib.pyplot as plt
from cassandra.cluster import Cluster
import requests
from fuzzywuzzy import fuzz
from collections import defaultdict
from fuzzywuzzy import process
from nltk.tokenize import word_tokenize
from settrade_v2 import Investor
from pprint import pprint
from settrade_v2 import Investor
from datetime import datetime
# Out:
# c:\Users\Imron\anaconda3\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Obtaining dependency information for fuzzywuzzy from https://files.pythonhosted.org/packages/43/ff/74f23998ad2f93b945c0309f825be92e04e0348e062026998b5eefef4c33/fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
# Note: you may need to restart the kernel to use updated packages.

# %%
cluster = Cluster(['127.0.0.1']) 
session = cluster.connect()

# %%
# สร้าง Keyspace หากยังไม่มี
session.execute("""
    CREATE KEYSPACE IF NOT EXISTS settrade_api 
    WITH replication = {'class': 'SimpleStrategy', 'replication_factor': 1}
""")

# ใช้ Keyspace ที่สร้างขึ้น
session.set_keyspace('settrade_api')

print("Keyspace 'settrade_api ' ถูกสร้างและใช้งานเรียบร้อย!")
# Out:
# Keyspace 'settrade_api ' ถูกสร้างและใช้งานเรียบร้อย!

# %%
investor = Investor(
                    app_id="Uuk5oH0xnQah5lB9",
                    app_secret="TuUD6z7tLF6gmr6YNKwEI0OoRhL0wJ2CYsy7VeS66qo=",
                    broker_id="SANDBOX",
                    app_code="SANDBOX",
                    is_auto_queue = False)

# %%
# กรณี Investor
market = investor.MarketData()


res = market.get_candlestick(
    symbol="BBL",
    interval="1d",
    limit=1,
    normalized=True,
)

print(res)
# Out:
# {'lastSequence': 420450, 'time': [1742144400], 'open': [200.0], 'high': [201.0], 'low': [143.5], 'close': [146.5], 'volume': [573700], 'value': [93237750.0]}

# %%
print(res)
print(type(res))
# Out:
# {'lastSequence': 420450, 'time': [1742144400], 'open': [200.0], 'high': [201.0], 'low': [143.5], 'close': [146.5], 'volume': [573700], 'value': [93237750.0]}
# <class 'dict'>

# %%
# 👉 เชื่อมต่อ Cassandra
cluster = Cluster(['127.0.0.1'])  # Localhost
session = cluster.connect()

# 👉 เลือกใช้ Keyspace
session.set_keyspace('settrade_api')

# 👉 ตรวจสอบและสร้างตาราง (ถ้ายังไม่มี)
session.execute("""
    CREATE TABLE IF NOT EXISTS candlestick_data (
        symbol TEXT,
        time TIMESTAMP PRIMARY KEY,
        open_price FLOAT,
        high_price FLOAT,
        low_price FLOAT,
        close_price FLOAT,
        volume INT,
        value FLOAT
    )
""")
print("✅ Keyspace และ Table พร้อมใช้งาน!")

# 👉 ฟังก์ชันดึงข้อมูลหุ้น
def fetch_and_store_stock(symbol="BBL", interval="1d", limit=10):
    res = market.get_candlestick(symbol=symbol, interval=interval, limit=limit, normalized=True)

    if not res:
        print(f"⚠️ ไม่พบข้อมูลสำหรับ {symbol}")
        return

    for i in range(len(res["time"])):
        timestamp = datetime.fromtimestamp(res["time"][i])  
        open_price = res["open"][i]
        high_price = res["high"][i]
        low_price = res["low"][i]
        close_price = res["close"][i]
        volume = res["volume"][i]
        value = res["value"][i]

        session.execute("""
            INSERT INTO candlestick_data (symbol, time, open_price, high_price, low_price, close_price, volume, value)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
        """, (symbol, timestamp, open_price, high_price, low_price, close_price, volume, value))

    print(f"✅ เพิ่มข้อมูล {len(res['time'])} รายการของหุ้น {symbol} สำเร็จ!")

# 👉 ทดสอบดึงข้อมูลหุ้น BBL
fetch_and_store_stock(symbol="BBL", interval="1d", limit=10)
# Out:
# ✅ Keyspace และ Table พร้อมใช้งาน!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BBL สำเร็จ!

# %%
from cassandra.cluster import Cluster

# 👉 เชื่อมต่อ Cassandra
cluster = Cluster(['127.0.0.1'])  # ถ้าเป็น localhost
session = cluster.connect()

# 👉 เลือก Keyspace
session.set_keyspace('settrade_api')

# 👉 ดึงรายชื่อตารางทั้งหมดใน Keyspace
rows = session.execute("SELECT table_name FROM system_schema.tables WHERE keyspace_name = 'stock_data'")

print("📌 ตารางที่อยู่ใน Keyspace 'stock_data':")
for row in rows:
    print("-", row.table_name)

# 👉 เช็คโครงสร้างของตาราง candlestick_data
table_info = session.execute("SELECT * FROM system_schema.columns WHERE keyspace_name = 'stock_data' AND table_name = 'candlestick_data'")

print("\n📌 โครงสร้างของตาราง 'candlestick_data':")
for column in table_info:
    print("-", column.column_name, column.type)
# Out:
# 📌 ตารางที่อยู่ใน Keyspace 'stock_data':
#
# 📌 โครงสร้างของตาราง 'candlestick_data':

# %%
import pandas as pd
import time

# ✅ โหลดรายชื่อหุ้นทั้งหมดจากไฟล์ CSV
try:
    symbols_df = pd.read_csv("thai_stocks-1.csv")  # ไฟล์ต้องมีคอลัมน์ 'symbol'
    symbols = symbols_df['symbol'].dropna().tolist()
except FileNotFoundError:
    print("❌ ไม่พบไฟล์ 'thai_stocks.csv' ใช้รายชื่อหุ้นที่กำหนดแทน")
    symbols = ["PTT", "AOT", "SCB", "CPALL", "ADVANC"]

# ✅ ฟังก์ชันที่ดึงข้อมูล Financial Data สำหรับหุ้นแต่ละตัว
def insert_financial_data(symbol):
    try:
        # 👉 ดึงข้อมูลจาก Settrade API หรือแหล่งข้อมูลอื่น ๆ
        res = market.get_candlestick(symbol=symbol, interval="1d", limit=10, normalized=True)

        if not res:
            print(f"⚠️ ไม่พบข้อมูลสำหรับ {symbol}")
            return

        # 👉 เชื่อมต่อ Cassandra (หรือฐานข้อมูลอื่น ๆ)
        from cassandra.cluster import Cluster
        cluster = Cluster(['127.0.0.1'])  # ถ้าเป็น localhost
        session = cluster.connect()
        session.set_keyspace('settrade_api')

        # 👉 วนลูปเก็บข้อมูล
        for i in range(len(res["time"])):
            timestamp = datetime.fromtimestamp(res["time"][i])  
            open_price = res["open"][i]
            high_price = res["high"][i]
            low_price = res["low"][i]
            close_price = res["close"][i]
            volume = res["volume"][i]
            value = res["value"][i]

            # 👉 แทรกข้อมูลลงในตาราง
            session.execute("""
                INSERT INTO candlestick_data (symbol, time, open_price, high_price, low_price, close_price, volume, value)
                VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
            """, (symbol, timestamp, open_price, high_price, low_price, close_price, volume, value))

        print(f"✅ เพิ่มข้อมูล {len(res['time'])} รายการของหุ้น {symbol} สำเร็จ!")

    except Exception as e:
        print(f"❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น {symbol}: {e}")

# ✅ ดึงข้อมูล Financial Data สำหรับหุ้นทุกตัว
for symbol in symbols:
    insert_financial_data(symbol)
    time.sleep(2)  # ⏳ ควบคุม API Rate Limit
# Out:
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น 24CS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น 2S สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น 3BBIF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น A สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น A5 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AAI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AAV สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ABM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ACAP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ACC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ACE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ACG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ADB สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ADD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ADVANC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ADVICE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AEONTS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AFC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AGE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AHC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AIE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AIMCG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AIMIRT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AIRA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AJ สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AJA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AKP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AKR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AKS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ALLA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ALLY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ALPHAX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ALT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ALUCON สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMANAH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMARC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMARIN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMATA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMATAR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMATAV สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AMR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ANAN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ANI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AOT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น APCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น APCS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น APO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น APP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น APURE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AQUA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ARIN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ARIP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ARROW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASAP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASEFA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASIA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASIAN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASIMAR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ASW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ATP30 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AU สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AUCT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AURA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AWC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AXTRART สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น AYUD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น B สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น B52 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BAFS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BAM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BANPU สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BAREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BAY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BBGI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BBIK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BBL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BCH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BCP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BCPG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BCT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BDMS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BE8 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BEAUTY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BEC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BEM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BEYOND สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BGC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BGRIM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BGT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BIG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BIOTEC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BIS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BIZ สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BJC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BJCHI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BKD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BKGI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BKIH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BLA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BLAND สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BLC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BLESS สำเร็จ!
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น BLISS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BOFFICE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BOL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BPP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BPS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BRI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BROCK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BRR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BRRGIF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BSBM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BSM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BSRC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BTC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BTG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BTNC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BTS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BTSGIF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BTW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BUI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BVG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BWG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น B-WORK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น BYD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CAZ สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CBG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CCET สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CCP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CEN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CENTEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CEYE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CFARM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CFRESH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CGD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CGH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHAO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHARAN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHASE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHAYO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHEWA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHIC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHOTI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CHOW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CIG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CIMBT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CITY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CIVIL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CKP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CMAN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CMC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CMO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CMR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CNT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น COCOCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น COLOR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น COM7 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น COMAN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPALL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPANEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPAXT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPNCG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPNREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPTREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CPW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CRANE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CRC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CRD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CREDIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CSC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CSP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CSR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CSS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CTARAF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CTW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CV สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น CWT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น D สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DCC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DCON สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DDD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DELTA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DEMCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DEXON สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DHOUSE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DIF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DIMET สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DITTO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DMT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DOD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DOHOME สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DPAINT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DRT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DTCENT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DTCI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DUSIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น DV8 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EASON สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EASTW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ECF สำเร็จ!
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น ECL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EFORL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EGATIF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EGCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EKH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EMC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EPG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ERW สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ESTAR สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ETC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ETE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ETL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EURO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น EVER สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น F&D สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FANCY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FLOYD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FMT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FNS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FORTH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FPI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FPT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FSMART สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FSX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FTE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FTI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FTREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FUTURERT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น FVC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GABLE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GAHREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GBX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GCAP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GENCO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GFC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GFPT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GGC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GJS สำเร็จ!
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น GL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GLAND สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GLOBAL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GLOCON สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GLORY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GPI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GPSC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GRAMMY สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GRAND สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GREEN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GROREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น GSTEEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GTB สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GTV สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GULF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GUNKUL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GVREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น GYT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HANA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HARN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HEALTH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HENG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HFT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HMPRO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HPF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HPT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HTC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HTECH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HUMAN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HYDRO สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น HYDROGEN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น I2 สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ICC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ICHI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ICN สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IFS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IHL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IIG สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น III สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ILINK สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ILM สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IMH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IMPACT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IND สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INET สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INETREIT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INGRS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INOX สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INSET สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INSURE สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น INTUCH สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IRC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IRCP สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IROYAL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IRPC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ISSARA สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IT สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ITC สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ITD สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ITEL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ITNS สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น ITTHI สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IVF สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น IVL สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น J สำเร็จ!
# ✅ เพิ่มข้อมูล 10 รายการของหุ้น JAK สำเร็จ!
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JAS: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JCK: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JCKH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JCT: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JDF: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JKN: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JMART: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JMT: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JPARK: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JR: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JSP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JTS: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น JUBILE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น K: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KAMART: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KASET: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KBANK: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KBS: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KBSPIF: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KCAR: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KCC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KCE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KCG: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KCM: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KDH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KEX: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KGEN: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KGI: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KIAT: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KISS: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KJL: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KK: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KKC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น KKP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น
: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TEKA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TERA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TFFIF: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TFG: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TFI: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TFM: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TFMAMA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TGE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TGH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TGPRO: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THAI: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THANA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THANI: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THCOM: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THG: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THIP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THMUI: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THRE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น THREL: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TIDLOR: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TIF1: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TIGER: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TIPCO: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TIPH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TISCO: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TITLE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TK: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TKC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TKN: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TKS: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TKT: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TLHPF: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TLI: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TM: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMAN: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMD: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMI: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMILL: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMT: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TMW: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNDT: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNITY: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNL: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNPC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNPF: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TNR: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TOA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TOG: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TOP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TOPP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPAC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPBI: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPCH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPCS: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPIPL: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPIPP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPL: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPLAS: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPOLY: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPRIME: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TPS: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TQM: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TQR: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TR: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRITN: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRT: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRU: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRUBB: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRUE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TRV: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TSC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TSE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TSI: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TSR: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TSTE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TSTH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTB: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTCL: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTI: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTLPF: Extra data: line 1 column 5 (char 4)
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTT: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TTW: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TU: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TU-PF: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TURTLE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TVDH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TVH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TVO: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TVT: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TWP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TWPC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TWZ: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น TYCN: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UAC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UBA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UBE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UBIS: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UEC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UKEM: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UMI: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UMS: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UNIQ: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UOBKH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UPF: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UPOIC: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UREKA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UTP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UV: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น UVAN: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VARO: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VCOM: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VGI: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VIBHA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VIH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VL: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VNG: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VPO: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VRANDA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น VS: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WACOAL: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WARRIX: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WAVE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WELL: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WFX: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WGE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WHA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WHABT: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WHAIR: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WHART: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WHAUP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WICE: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WIIK: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WIN: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WINDOW: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WINMED: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WINNER: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WORK: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WP: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น WPH: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น XBIO: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น XO: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น XPG: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น YGG: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น YONG: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น YUASA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น ZAA: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น ZEN: The access token is invalid or has expired
# ❌ เกิดข้อผิดพลาดในการดึงข้อมูลของหุ้น ZIGA: The access token is invalid or has expired

# %%
from cassandra.cluster import Cluster
import pandas as pd

# เชื่อมต่อกับ Cassandra
cluster = Cluster(['127.0.0.1'])  # ระบุ IP ของ Cassandra node ที่คุณใช้งาน
session = cluster.connect('settrade_api')  # เปลี่ยนเป็น keyspace ของคุณ

# สั่งเลือกข้อมูลจากตาราง candlestick_data
symbol = "SAM"
query = f"SELECT time, open_price, high_price, low_price, close_price FROM candlestick_data WHERE symbol = '{symbol}' ALLOW FILTERING;"

# ดึงข้อมูลจาก Cassandra
rows = session.execute(query)

# สร้าง DataFrame จากผลลัพธ์
data = []
for row in rows:
    data.append({
        "time": row.time,
        "open_price": row.open_price,
        "high_price": row.high_price,
        "low_price": row.low_price,
        "close_price": row.close_price
    })

df = pd.DataFrame(data)

# แสดง DataFrame
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from cassandra.cluster import Cluster
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime


# Plotting the stock data using Matplotlib
plt.figure(figsize=(10, 6))

# Plot Close Price
plt.plot(df['time'], df['close_price'], label="Close Price", color='blue', marker='o')

# Plot Open Price
plt.plot(df['time'], df['open_price'], label="Open Price", color='green', marker='x')

# Plot High Price
plt.plot(df['time'], df['high_price'], label="High Price", color='red', marker='^')

# Plot Low Price
plt.plot(df['time'], df['low_price'], label="Low Price", color='orange', marker='v')

# Adding labels and title
plt.title('Stock Price Movement for BBL', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (THB)', fontsize=12)
plt.legend(loc='best')

# Formatting the x-axis to show dates properly
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 11
#       8 plt.figure(figsize=(10, 6))
#      10 # Plot Close Price
# ---> 11 plt.plot(df['time'], df['close_price'], label="Close Price", color='blue', marker='o')
#      13 # Plot Open Price
#      14 plt.plot(df['time'], df['open_price'], label="Open Price", color='green', marker='x')
#
# File c:\Users\Imron\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\Imron\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:349, in RangeIndex.get_loc(self, key)
#     347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
# --> 349     raise KeyError(key)
#     350 self._check_indexing_error(key)
#     351 raise KeyError(key)
#
# KeyError: 'time'
